# %%
import os
from langchain_openai import ChatOpenAI

model = ChatOpenAI(
    model='Qwen/Qwen3-Omni-30B-A3B-Instruct',
    base_url=os.environ.get('OPENAI_BASE_URL'),
    api_key=os.environ.get('OPENAI_API_KEY')
)

# %%
from langchain_core.messages import SystemMessage, HumanMessage

msg = [
    SystemMessage(content="将以下内容翻译为意大利语"),
    HumanMessage(content="你好，请问你要去哪里?")
]

model.invoke(msg)
# Out:
# AIMessage(content='Ciao, dove vuoi andare?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 9, 'prompt_tokens': 26, 'total_tokens': 35, 'completion_tokens_details': None, 'prompt_tokens_details': None}, 'model_provider': 'openai', 'model_name': 'Qwen/Qwen3-Omni-30B-A3B-Instruct', 'system_fingerprint': '', 'id': '019d14be462ce8696f5a866f99e31e29', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019d14be-43bd-72b3-9aae-4538d25d541a-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 26, 'output_tokens': 9, 'total_tokens': 35, 'input_token_details': {}, 'output_token_details': {}})

# %%
from langchain_core.output_parsers import StrOutputParser

# 结果解析器
parser = StrOutputParser()  # 最简单的文本结果解析器
parser.parse(model.invoke(msg))
# Out:
# AIMessage(content='Pronto, scusa, dove vuoi andare?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 12, 'prompt_tokens': 26, 'total_tokens': 38, 'completion_tokens_details': None, 'prompt_tokens_details': None}, 'model_provider': 'openai', 'model_name': 'Qwen/Qwen3-Omni-30B-A3B-Instruct', 'system_fingerprint': '', 'id': '019d14be4890d98dea797e7f94c57c23', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019d14be-46af-7640-9f38-c1ea75aa59eb-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 26, 'output_tokens': 12, 'total_tokens': 38, 'input_token_details': {}, 'output_token_details': {}})

# %%
# 创建简单的chain
chain = model | parser
chain.invoke(msg)
# Out:
# 'Ciao, dove stai andando?'
